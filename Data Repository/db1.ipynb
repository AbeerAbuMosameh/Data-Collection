# %%
# Step 1 : Data Collection and Understanding 
# Import libraries used in data preparation
import pandas as pd
import numpy as np

# %%
# Load the heart dataset .. in same folder
dataset = pd.read_csv("heart.csv") #load dataset into a pandas DataFrame.
dataset #to ensure read it successfully
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
# get the dataset Size
size = dataset.shape
size
# Out:
# (1025, 14)

# %%
# get the dataset dimension
dimension = dataset.ndim
dimension
# Out:
# 2

# %%
# get columns' titles
titles = dataset.columns
titles
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
 #describing a certain column with some basic statistics
desc = dataset['target'].describe()
desc
# Out:
# count    1025.000000
# mean        0.513171
# std         0.500070
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
# Step 2 : Data Exploration
# Display the first 5 rows of the dataset
head = dataset.head()
head
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Display information about the dataset
info = dataset.info() 
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# Display descriptive statistics of the edited dataset
desc = dataset.describe() 
desc
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
# Step 3 : Data Cleaning and preperation 
data = pd.read_csv("heart_after_edit.csv") #load edit dataset into a pandas DataFrame.
data #to ensure read it successfully
# Out:
#       index   age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0         1  52.0    1   0       125  212.0  0.0        1      168    0.0
# 1         2  53.0    5   0       120  203.0  1.0        0      155    1.0
# 2         3   NaN    1   0       145  174.0  0.0        1      125    1.0
# 3         4  61.0    1   0       148  203.0  0.0        1      161    0.0
# 4         5  62.0    0   0       138  294.0  1.0        1      106    0.0
# ...     ...   ...  ...  ..       ...    ...  ...      ...      ...    ...
# 1020   1021  59.0    1   1       140  221.0  0.0        1      164    1.0
# 1021   1022  60.0    1   0       125  258.0  0.0        0      141    1.0
# 1022   1023  47.0    1   0       110  275.0  0.0        0      118    1.0
# 1023   1024  50.0    0   0       110  254.0  0.0        0      159    0.0
# 1024   1025  54.0    1   0       120  188.0  0.0        1      113    0.0
#
#      oldpeak  slope  ca  thal  target
# 0          1      2   2     3     0.0
# 1        3.1      0   0     3     0.0
# 2        2.6      0   0     3     0.0
# 3          0      2   1     3     NaN
# 4        1.9      1   3     2     0.0
# ...      ...    ...  ..   ...     ...
# 1020       0      2   0     2     1.0
# 1021     2.8      1   1     3     0.0
# 1022       1      1   1     2     0.0
# 1023       0      2   0     2     1.0
# 1024     1.4      1   1     3     0.0
#
# [1025 rows x 15 columns]

# %%
data.rename(columns={'sex': 'gender'}, inplace=True) #rename coulmn
data.columns
# Out:
# Index(['index', 'age', 'gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
 #rename coulmn - more clear
data.columns = ['index', 'age', 'gender', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_electro', 'max_heart_rate',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thal', 'target']

data.columns
# Out:
# Index(['index', 'age', 'gender', 'chest_pain_type', 'resting_blood_pressure',
#        'cholesterol', 'fasting_blood_sugar', 'rest_electro', 'max_heart_rate',
#        'exercise_induced_angina', 'st_depression', 'st_slope',
#        'num_major_vessels', 'thal', 'target'],
#       dtype='object')

# %%
desc = data.describe() 
desc # Display descriptive statistics of the edited dataset
# Out:
#              index          age       gender  chest_pain_type  \
# count  1025.000000  1024.000000  1025.000000      1025.000000
# mean    512.649756    54.418945     0.699512         0.942439
# std     296.416605     9.063654     0.479512         1.029641
# min       1.000000    29.000000     0.000000         0.000000
# 25%     256.000000    48.000000     0.000000         0.000000
# 50%     513.000000    56.000000     1.000000         1.000000
# 75%     769.000000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     5.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1025.000000  1024.000000          1024.000000   1025.000000
# mean               184.712195   246.045898             0.149414      0.534634
# std               1699.772051    51.596779             0.356670      0.545776
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.000000             0.000000      1.000000
# max              54548.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1025.000000              1024.000000  1025.000000
# mean       149.114146                 0.335938     1.385366
# std         23.005724                 0.472548     0.617755
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1025.000000  1025.000000  1023.000000
# mean            0.754146     2.323902     0.514174
# std             1.030798     0.620660     0.500044
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
#count missing values in each attribute
missing = pd.DataFrame({'missing': data.isnull().sum()})
missing
# Out:
#                          missing
# index                          0
# age                            1
# gender                         0
# chest_pain_type                0
# resting_blood_pressure         0
# cholesterol                    1
# fasting_blood_sugar            1
# rest_electro                   0
# max_heart_rate                 0
# exercise_induced_angina        1
# st_depression                  0
# st_slope                       0
# num_major_vessels              0
# thal                           0
# target                         2

# %%
# print target coulmn to say data
data['target']
# Out:
# 0       0.0
# 1       0.0
# 2       0.0
# 3       NaN
# 4       0.0
#        ...
# 1020    1.0
# 1021    0.0
# 1022    0.0
# 1023    1.0
# 1024    0.0
# Name: target, Length: 1025, dtype: float64

# %%
# target column is numeric 
data['target'] = pd.to_numeric(data['target'], errors='coerce') 

# Drop rows with missing target values empty or null
# data = data.dropna(subset=['target']) or
data = data[pd.notnull(data['target'])]

# convert to int type 
data['target'] = data['target'].astype(int) 

# drop rows where target values are not 0 or 1 
data = data[data['target'].isin([0, 1])].reset_index(drop=True) 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    1023 non-null   int64
#  1   age                      1022 non-null   float64
#  2   gender                   1023 non-null   int64
#  3   chest_pain_type          1023 non-null   int64
#  4   resting_blood_pressure   1023 non-null   int64
#  5   cholesterol              1022 non-null   float64
#  6   fasting_blood_sugar      1022 non-null   float64
#  7   rest_electro             1023 non-null   int64
#  8   max_heart_rate           1023 non-null   int64
#  9   exercise_induced_angina  1022 non-null   float64
#  10  st_depression            1023 non-null   object
#  11  st_slope                 1023 non-null   int64
#  12  num_major_vessels        1023 non-null   int64
#  13  thal                     1023 non-null   int64
#  14  target                   1023 non-null   int32
# dtypes: float64(4), int32(1), int64(9), object(1)
# memory usage: 116.0+ KB
# C:\Users\HP\AppData\Local\Temp\ipykernel_21216\3058665240.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['target'] = data['target'].astype(int)

# %%
data['target']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1018    1
# 1019    0
# 1020    0
# 1021    1
# 1022    0
# Name: target, Length: 1023, dtype: int32

# %%
data = data[pd.notnull(data['cholesterol'])]

# %%
#count missing values in each attribute
missing = pd.DataFrame({'missing': data.isnull().sum()})
missing
# Out:
#                          missing
# index                          0
# age                            1
# gender                         0
# chest_pain_type                0
# resting_blood_pressure         0
# cholesterol                    0
# fasting_blood_sugar            1
# rest_electro                   0
# max_heart_rate                 0
# exercise_induced_angina        1
# st_depression                  0
# st_slope                       0
# num_major_vessels              0
# thal                           0
# target                         0

# %%
# show age befor processing
data['age']
# Out:
# 0       52.0
# 1       53.0
# 2        NaN
# 3       62.0
# 4       58.0
#         ...
# 1018    59.0
# 1019    60.0
# 1020    47.0
# 1021    50.0
# 1022    54.0
# Name: age, Length: 1022, dtype: float64

# %%
# Ensure age column is numeric 
data['age'] = pd.to_numeric(data['age'], errors='coerce') 

# Drop rows with missing age values and reset index 
data = data.dropna(subset=['age']).reset_index(drop=True)
# or do this data = data['age'].fillna(data['age'].mean())
data['age']
# Out:
# 0       52.0
# 1       53.0
# 2       62.0
# 3       58.0
# 4       58.0
#         ...
# 1016    59.0
# 1017    60.0
# 1018    47.0
# 1019    50.0
# 1020    54.0
# Name: age, Length: 1021, dtype: float64

# %%
data.describe()
# Out:
#              index          age       gender  chest_pain_type  \
# count  1021.000000  1021.000000  1021.000000      1021.000000
# mean    514.476983    54.421156     0.698335         0.941234
# std     295.524507     9.061711     0.480081         1.028264
# min       1.000000    29.000000     0.000000         0.000000
# 25%     259.000000    48.000000     0.000000         0.000000
# 50%     515.000000    56.000000     1.000000         1.000000
# 75%     770.000000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     5.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1021.000000  1021.000000          1020.000000   1021.000000
# mean               184.874633   246.218413             0.150000      0.533790
# std               1703.099676    51.570039             0.357247      0.546005
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.000000             0.000000      1.000000
# max              54548.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1021.000000              1020.000000  1021.000000
# mean       149.092067                 0.335294     1.385896
# std         23.016902                 0.472325     0.616725
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1021.000000  1021.000000  1021.000000
# mean            0.756121     2.322233     0.514202
# std             1.031976     0.620709     0.500043
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
# removing rows where gender is either 0 or 1 and reset index
data = data[data['gender'].isin([0, 1])]

data.reset_index(drop=True, inplace=True)

data.describe()
# Out:
#              index          age       gender  chest_pain_type  \
# count  1020.000000  1020.000000  1020.000000      1020.000000
# mean    514.979412    54.422549     0.694118         0.942157
# std     295.232878     9.066047     0.461006         1.028346
# min       1.000000    29.000000     0.000000         0.000000
# 25%     259.750000    48.000000     0.000000         0.000000
# 50%     515.500000    56.000000     1.000000         1.000000
# 75%     770.250000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     1.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1020.000000  1020.000000          1019.000000   1020.000000
# mean               184.938235   246.260784             0.149166      0.534314
# std               1703.933930    51.577553             0.356427      0.546017
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.250000             0.000000      1.000000
# max              54548.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1020.000000              1019.000000  1020.000000
# mean       149.086275                 0.334642     1.387255
# std         23.027449                 0.472097     0.615497
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1020.000000  1020.000000  1020.000000
# mean            0.756863     2.321569     0.514706
# std             1.032210     0.620650     0.500029
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
# rows where the fasting_blood_sugar column has empty values
before = data[data['fasting_blood_sugar'].isna()]
before
# Out:
#      index   age  gender  chest_pain_type  resting_blood_pressure  \
# 978    984  64.0       1                0                     128
#
#      cholesterol  fasting_blood_sugar  rest_electro  max_heart_rate  \
# 978        263.0                  NaN             1             105
#
#      exercise_induced_angina st_depression  st_slope  num_major_vessels  thal  \
# 978                      1.0           0.2         1                  1     3
#
#      target
# 978       1

# %%
# Replace NaN values in fasting_blood_sugar column with the mean
data['fasting_blood_sugar'].fillna(data['fasting_blood_sugar'].mean(), inplace=True)

#row after replacement
after_row = data.loc[979]
print("Row with index 979 after replacement:")
print(after_row)
# Out:
# Row with index 979 after replacement:
# index                        985
# age                         59.0
# gender                         1
# chest_pain_type                0
# resting_blood_pressure       135
# cholesterol                234.0
# fasting_blood_sugar          0.0
# rest_electro                   1
# max_heart_rate               161
# exercise_induced_angina      0.0
# st_depression                0.5
# st_slope                       1
# num_major_vessels              0
# thal                           3
# target                         1
# Name: 979, dtype: object
# C:\Users\HP\AppData\Local\Temp\ipykernel_21216\4293921480.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['fasting_blood_sugar'].fillna(data['fasting_blood_sugar'].mean(), inplace=True)

# %%
data.describe()
# Out:
#              index          age       gender  chest_pain_type  \
# count  1020.000000  1020.000000  1020.000000      1020.000000
# mean    514.979412    54.422549     0.694118         0.942157
# std     295.232878     9.066047     0.461006         1.028346
# min       1.000000    29.000000     0.000000         0.000000
# 25%     259.750000    48.000000     0.000000         0.000000
# 50%     515.500000    56.000000     1.000000         1.000000
# 75%     770.250000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     1.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1020.000000  1020.000000          1020.000000   1020.000000
# mean               184.938235   246.260784             0.149166      0.534314
# std               1703.933930    51.577553             0.356252      0.546017
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.250000             0.000000      1.000000
# max              54548.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1020.000000              1019.000000  1020.000000
# mean       149.086275                 0.334642     1.387255
# std         23.027449                 0.472097     0.615497
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1020.000000  1020.000000  1020.000000
# mean            0.756863     2.321569     0.514706
# std             1.032210     0.620650     0.500029
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
# rows where the exercise_induced_angina column has empty values
before = data[data['exercise_induced_angina'].isna()]
before
# Out:
#    index   age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 4      8  55.0       1                0                     160        289.0
#
#    fasting_blood_sugar  rest_electro  max_heart_rate  exercise_induced_angina  \
# 4                  0.0             0             145                      NaN
#
#   st_depression  st_slope  num_major_vessels  thal  target
# 4           0.8         1                  1     3       0

# %%
# Replace NaN values in exercise_induced_angina column with the median 
data['exercise_induced_angina'].fillna(data['exercise_induced_angina'].median(), inplace=True)

#row after replacement
after_row = data.loc[4]
print("Row with index 4 after replacement:")
print(after_row)
# Out:
# Row with index 4 after replacement:
# index                          8
# age                         55.0
# gender                         1
# chest_pain_type                0
# resting_blood_pressure       160
# cholesterol                289.0
# fasting_blood_sugar          0.0
# rest_electro                   0
# max_heart_rate               145
# exercise_induced_angina      0.0
# st_depression                0.8
# st_slope                       1
# num_major_vessels              1
# thal                           3
# target                         0
# Name: 4, dtype: object
# C:\Users\HP\AppData\Local\Temp\ipykernel_21216\2203889533.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['exercise_induced_angina'].fillna(data['exercise_induced_angina'].median(), inplace=True)

# %%
data.describe()
# Out:
#              index          age       gender  chest_pain_type  \
# count  1020.000000  1020.000000  1020.000000      1020.000000
# mean    514.979412    54.422549     0.694118         0.942157
# std     295.232878     9.066047     0.461006         1.028346
# min       1.000000    29.000000     0.000000         0.000000
# 25%     259.750000    48.000000     0.000000         0.000000
# 50%     515.500000    56.000000     1.000000         1.000000
# 75%     770.250000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     1.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1020.000000  1020.000000          1020.000000   1020.000000
# mean               184.938235   246.260784             0.149166      0.534314
# std               1703.933930    51.577553             0.356252      0.546017
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.250000             0.000000      1.000000
# max              54548.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1020.000000              1020.000000  1020.000000
# mean       149.086275                 0.334314     1.387255
# std         23.027449                 0.471981     0.615497
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1020.000000  1020.000000  1020.000000
# mean            0.756863     2.321569     0.514706
# std             1.032210     0.620650     0.500029
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
# Find max value in the resting_blood_pressure column
index = data['resting_blood_pressure'].idxmax()
#or data[data.resting_blood_pressure == 54548]

print(f"index : {index}, \nrow data : \n{data.loc[index]} ")
# Out:
# index : 2,
# row data :
# index                          6
# age                         58.0
# gender                         0
# chest_pain_type                0
# resting_blood_pressure     54548
# cholesterol                248.0
# fasting_blood_sugar          0.0
# rest_electro                   0
# max_heart_rate               122
# exercise_induced_angina      0.0
# st_depression                  1
# st_slope                       1
# num_major_vessels              0
# thal                           2
# target                         1
# Name: 2, dtype: object

# %%
# Manually update the value of resting_blood_pressure 
data.at[index, 'resting_blood_pressure'] = 120  
# or data [120 , 4] = 120

data.loc[index]
# Out:
# index                          6
# age                         58.0
# gender                         0
# chest_pain_type                0
# resting_blood_pressure       120
# cholesterol                248.0
# fasting_blood_sugar          0.0
# rest_electro                   0
# max_heart_rate               122
# exercise_induced_angina      0.0
# st_depression                  1
# st_slope                       1
# num_major_vessels              0
# thal                           2
# target                         1
# Name: 2, dtype: object

# %%
data.describe()
# Out:
#              index          age       gender  chest_pain_type  \
# count  1020.000000  1020.000000  1020.000000      1020.000000
# mean    514.979412    54.422549     0.694118         0.942157
# std     295.232878     9.066047     0.461006         1.028346
# min       1.000000    29.000000     0.000000         0.000000
# 25%     259.750000    48.000000     0.000000         0.000000
# 50%     515.500000    56.000000     1.000000         1.000000
# 75%     770.250000    61.000000     1.000000         2.000000
# max    1025.000000    77.000000     1.000000         3.000000
#
#        resting_blood_pressure  cholesterol  fasting_blood_sugar  rest_electro  \
# count             1020.000000  1020.000000          1020.000000   1020.000000
# mean               131.577451   246.260784             0.149166      0.534314
# std                 17.516987    51.577553             0.356252      0.546017
# min                 94.000000   126.000000             0.000000      0.000000
# 25%                120.000000   211.000000             0.000000      0.000000
# 50%                130.000000   240.000000             0.000000      1.000000
# 75%                140.000000   275.250000             0.000000      1.000000
# max                200.000000   564.000000             1.000000      5.000000
#
#        max_heart_rate  exercise_induced_angina     st_slope  \
# count     1020.000000              1020.000000  1020.000000
# mean       149.086275                 0.334314     1.387255
# std         23.027449                 0.471981     0.615497
# min         71.000000                 0.000000     0.000000
# 25%        132.000000                 0.000000     1.000000
# 50%        152.000000                 0.000000     1.000000
# 75%        166.000000                 1.000000     2.000000
# max        202.000000                 1.000000     2.000000
#
#        num_major_vessels         thal       target
# count        1020.000000  1020.000000  1020.000000
# mean            0.756863     2.321569     0.514706
# std             1.032210     0.620650     0.500029
# min             0.000000     0.000000     0.000000
# 25%             0.000000     2.000000     0.000000
# 50%             0.000000     2.000000     1.000000
# 75%             1.000000     3.000000     1.000000
# max             4.000000     3.000000     1.000000

# %%
# Define the list of columns to check for duplicates
subset_list = ['index','age', 'gender', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol',
               'fasting_blood_sugar', 'rest_electro', 'max_heart_rate', 'exercise_induced_angina',
               'st_depression', 'st_slope', 'num_major_vessels', 'thal', 'target']

#duplicate rows
duplicates = data[data.duplicated(subset=subset_list, keep='first')]

duplicates
# Out:
#      index   age  gender  chest_pain_type  resting_blood_pressure  \
# 365     12  43.0       0                0                     132
#
#      cholesterol  fasting_blood_sugar  rest_electro  max_heart_rate  \
# 365        341.0                  1.0             0             136
#
#      exercise_induced_angina st_depression  st_slope  num_major_vessels  thal  \
# 365                      1.0             3         1                  0     3
#
#      target
# 365       0

# %%
# Remove duplicate rows, keeping the first occurrence
data.drop_duplicates(subset=subset_list, keep='first', inplace=True)
data.head()
# Out:
#    index   age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0      1  52.0       1                0                     125        212.0
# 1      5  62.0       0                0                     138        294.0
# 2      6  58.0       0                0                     120        248.0
# 3      7  58.0       1                0                     114        318.0
# 4      8  55.0       1                0                     160        289.0
#
#    fasting_blood_sugar  rest_electro  max_heart_rate  exercise_induced_angina  \
# 0                  0.0             1             168                      0.0
# 1                  1.0             1             106                      0.0
# 2                  0.0             0             122                      0.0
# 3                  0.0             2             140                      0.0
# 4                  0.0             0             145                      0.0
#
#   st_depression  st_slope  num_major_vessels  thal  target
# 0             1         2                  2     3       0
# 1           1.9         1                  3     2       0
# 2             1         1                  0     2       1
# 3           4.4         0                  3     1       0
# 4           0.8         1                  1     3       0

# %%
data.drop(columns=['index'], inplace=True)

# after delete column
data.head()
# Out:
#     age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0  52.0       1                0                     125        212.0
# 1  62.0       0                0                     138        294.0
# 2  58.0       0                0                     120        248.0
# 3  58.0       1                0                     114        318.0
# 4  55.0       1                0                     160        289.0
#
#    fasting_blood_sugar  rest_electro  max_heart_rate  exercise_induced_angina  \
# 0                  0.0             1             168                      0.0
# 1                  1.0             1             106                      0.0
# 2                  0.0             0             122                      0.0
# 3                  0.0             2             140                      0.0
# 4                  0.0             0             145                      0.0
#
#   st_depression  st_slope  num_major_vessels  thal  target
# 0             1         2                  2     3       0
# 1           1.9         1                  3     2       0
# 2             1         1                  0     2       1
# 3           4.4         0                  3     1       0
# 4           0.8         1                  1     3       0

# %%
#count missing values in each attribute
missing = pd.DataFrame({'missing': data.isnull().sum()})
missing
# Out:
#                          missing
# age                            0
# gender                         0
# chest_pain_type                0
# resting_blood_pressure         0
# cholesterol                    0
# fasting_blood_sugar            0
# rest_electro                   0
# max_heart_rate                 0
# exercise_induced_angina        0
# st_depression                  0
# st_slope                       0
# num_major_vessels              0
# thal                           0
# target                         0

# %%
import matplotlib.pyplot as plt

# Generate histograms for each column 
data.hist(figsize=(14, 10)) 
plt.show()

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                               age    gender  chest_pain_type  \
# age                      1.000000 -0.106591        -0.069117
# gender                  -0.106591  1.000000        -0.042919
# chest_pain_type         -0.069117 -0.042919         1.000000
# resting_blood_pressure   0.271897 -0.083037         0.037958
# cholesterol              0.226052 -0.193476        -0.080453
# fasting_blood_sugar      0.126832  0.030779         0.084529
# rest_electro            -0.141009 -0.049456         0.033273
# max_heart_rate          -0.389869 -0.051202         0.305136
# exercise_induced_angina  0.091559  0.139062        -0.402207
# st_depression            0.210532  0.085781        -0.175246
# st_slope                -0.166943 -0.025784         0.127964
# num_major_vessels        0.272324  0.112788        -0.176758
# thal                     0.073728  0.198584        -0.162205
# target                  -0.227754 -0.280452         0.433408
#
#                          resting_blood_pressure  cholesterol  \
# age                                    0.271897     0.226052
# gender                                -0.083037    -0.193476
# chest_pain_type                        0.037958    -0.080453
# resting_blood_pressure                 1.000000     0.132058
# cholesterol                            0.132058     1.000000
# fasting_blood_sugar                    0.182668     0.023185
# rest_electro                          -0.133394    -0.149652
# max_heart_rate                        -0.041252    -0.020255
# exercise_induced_angina                0.056057     0.066689
# st_depression                          0.186931     0.066780
# st_slope                              -0.120529    -0.017228
# num_major_vessels                      0.105512     0.073088
# thal                                   0.056386     0.102687
# target                                -0.136193    -0.102280
#
#                          fasting_blood_sugar  rest_electro  max_heart_rate  \
# age                                 0.126832     -0.141009       -0.389869
# gender                              0.030779     -0.049456       -0.051202
# chest_pain_type                     0.084529      0.033273        0.305136
# resting_blood_pressure              0.182668     -0.133394       -0.041252
# cholesterol                         0.023185     -0.149652       -0.020255
# fasting_blood_sugar                 1.000000     -0.099669       -0.008584
# rest_electro                       -0.099669      1.000000        0.057245
# max_heart_rate                     -0.008584      0.057245        1.000000
# exercise_induced_angina             0.045208     -0.068052       -0.381805
# st_depression                       0.003310     -0.053729       -0.350413
# st_slope                           -0.056519      0.089820        0.394794
# num_major_vessels                   0.140907     -0.074744       -0.208526
# thal                               -0.046116     -0.025777       -0.098842
# target                             -0.037169      0.119488        0.423103
#
#                          exercise_induced_angina  st_depression  st_slope  \
# age                                     0.091559       0.210532 -0.166943
# gender                                  0.139062       0.085781 -0.025784
# chest_pain_type                        -0.402207      -0.175246  0.127964
# resting_blood_pressure                  0.056057       0.186931 -0.120529
# cholesterol                             0.066689       0.066780 -0.017228
# fasting_blood_sugar                     0.045208       0.003310 -0.056519
# rest_electro                           -0.068052      -0.053729  0.089820
# max_heart_rate                         -0.381805      -0.350413  0.394794
# exercise_induced_angina                 1.000000       0.307802 -0.263112
# st_depression                           0.307802       1.000000 -0.572210
# st_slope                               -0.263112      -0.572210  1.000000
# num_major_vessels                       0.111762       0.227786 -0.077661
# thal                                    0.190894       0.202057 -0.091928
# target                                 -0.437981      -0.436465  0.342997
#
#                          num_major_vessels      thal    target
# age                               0.272324  0.073728 -0.227754
# gender                            0.112788  0.198584 -0.280452
# chest_pain_type                  -0.176758 -0.162205  0.433408
# resting_blood_pressure            0.105512  0.056386 -0.136193
# cholesterol                       0.073088  0.102687 -0.102280
# fasting_blood_sugar               0.140907 -0.046116 -0.037169
# rest_electro                     -0.074744 -0.025777  0.119488
# max_heart_rate                   -0.208526 -0.098842  0.423103
# exercise_induced_angina           0.111762  0.190894 -0.437981
# st_depression                     0.227786  0.202057 -0.436465
# st_slope                         -0.077661 -0.091928  0.342997
# num_major_vessels                 1.000000  0.152184 -0.385788
# thal                              0.152184  1.000000 -0.337061
# target                           -0.385788 -0.337061  1.000000

# %%
# Step 4: Feature Engineering
# Create a new feature based on age
bin_labels = ['Child', 'Teenager', 'Young Adult', 'Middle Aged', 'Senior']
data['age_group'] = pd.cut(data['age'], bins=[0, 12, 19, 35, 55, 100], labels=bin_labels)

# new feature
data[['age', 'age_group']]
# Out:
#        age    age_group
# 0     52.0  Middle Aged
# 1     62.0       Senior
# 2     58.0       Senior
# 3     58.0       Senior
# 4     55.0  Middle Aged
# ...    ...          ...
# 1015  59.0       Senior
# 1016  60.0       Senior
# 1017  47.0  Middle Aged
# 1018  50.0  Middle Aged
# 1019  54.0  Middle Aged
#
# [1019 rows x 2 columns]

# %%
# Create a new feature based on cholesterol 3 bins 0-200 , 200-240 , 240-1000
bin_labels = ['Good', 'Borderline', 'High']
data['chol_level'] = pd.cut(data['cholesterol'], bins=[0, 200, 240, 1000], labels=bin_labels)

data[['cholesterol', 'chol_level']]
# Out:
#       cholesterol  chol_level
# 0           212.0  Borderline
# 1           294.0        High
# 2           248.0        High
# 3           318.0        High
# 4           289.0        High
# ...           ...         ...
# 1015        221.0  Borderline
# 1016        258.0        High
# 1017        275.0        High
# 1018        254.0        High
# 1019        188.0        Good
#
# [1019 rows x 2 columns]

# %%
# step 5 : Data Transformation
from sklearn.preprocessing import MinMaxScaler

# 1. scaling/normalization numerical Features
minMaxScaler = MinMaxScaler()

# numeric features to normaliz
numeric_features = ['resting_blood_pressure', 'cholesterol', 'max_heart_rate']

# fit scaler to numeric features
minMaxScaler.fit(data[numeric_features])

# transform the numeric features
data[numeric_features] = minMaxScaler.fit_transform(data[numeric_features])

data.head()
# Out:
#     age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0  52.0       1                0                0.292453     0.196347
# 1  62.0       0                0                0.415094     0.383562
# 2  58.0       0                0                0.245283     0.278539
# 3  58.0       1                0                0.188679     0.438356
# 4  55.0       1                0                0.622642     0.372146
#
#    fasting_blood_sugar  rest_electro  max_heart_rate  exercise_induced_angina  \
# 0                  0.0             1        0.740458                      0.0
# 1                  1.0             1        0.267176                      0.0
# 2                  0.0             0        0.389313                      0.0
# 3                  0.0             2        0.526718                      0.0
# 4                  0.0             0        0.564885                      0.0
#
#   st_depression  st_slope  num_major_vessels  thal  target    age_group  \
# 0             1         2                  2     3       0  Middle Aged
# 1           1.9         1                  3     2       0       Senior
# 2             1         1                  0     2       1       Senior
# 3           4.4         0                  3     1       0       Senior
# 4           0.8         1                  1     3       0  Middle Aged
#
#    chol_level
# 0  Borderline
# 1        High
# 2        High
# 3        High
# 4        High

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# normalize age
data['age'] =minMaxScaler.fit_transform(data['age'].values.reshape(-1, 1))
data.head()
# Out:
#         age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0  0.479167       1                0                0.292453     0.196347
# 1  0.687500       0                0                0.415094     0.383562
# 2  0.604167       0                0                0.245283     0.278539
# 3  0.604167       1                0                0.188679     0.438356
# 4  0.541667       1                0                0.622642     0.372146
#
#    fasting_blood_sugar  rest_electro  max_heart_rate  exercise_induced_angina  \
# 0                  0.0             1        0.740458                      0.0
# 1                  1.0             1        0.267176                      0.0
# 2                  0.0             0        0.389313                      0.0
# 3                  0.0             2        0.526718                      0.0
# 4                  0.0             0        0.564885                      0.0
#
#   st_depression  st_slope  num_major_vessels  thal  target    age_group  \
# 0             1         2                  2     3       0  Middle Aged
# 1           1.9         1                  3     2       0       Senior
# 2             1         1                  0     2       1       Senior
# 3           4.4         0                  3     1       0       Senior
# 4           0.8         1                  1     3       0  Middle Aged
#
#    chol_level
# 0  Borderline
# 1        High
# 2        High
# 3        High
# 4        High

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# Calculate the IQR for restecg - interquartile range measure of  spread of the data
Q1 = data['rest_electro'].quantile(0.25) # Q1 represents the value below which 25% of the data points fall.
Q3 = data['rest_electro'].quantile(0.75) # Q3 represents the value below which 75% of the data points fall.

IQR = Q3 - Q1
 
# Determine the lower and upper bounds for outliers
lower_bound = Q1 - 1 * IQR
upper_bound = Q3 + 1 * IQR

# Identify outlier rows
outliers = data[(data['rest_electro'] < lower_bound) | (data['rest_electro'] > upper_bound)] #outside the range.

outliers
# Out:
#         age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 973  0.3125       1                0                0.150943       0.1621
#
#      fasting_blood_sugar  rest_electro  max_heart_rate  \
# 973                  0.0             5         0.80916
#
#      exercise_induced_angina st_depression  st_slope  num_major_vessels  thal  \
# 973                      0.0             0         2                  1     2
#
#      target    age_group chol_level
# 973       0  Middle Aged       Good

# %%
# Drop the row with index 974
data.drop([974],inplace=True, axis=0)
data.reset_index(drop=True, inplace=True)

after_row = data.loc[974]
print("Row with index 974 after delete privious:")
print(after_row)
# Out:
# Row with index 974 after delete privious:
# age                           0.208333
# gender                               1
# chest_pain_type                      0
# resting_blood_pressure        0.226415
# cholesterol                   0.212329
# fasting_blood_sugar                0.0
# rest_electro                         1
# max_heart_rate                0.526718
# exercise_induced_angina            0.0
# st_depression                      1.2
# st_slope                             1
# num_major_vessels                    0
# thal                                 3
# target                               0
# age_group                  Middle Aged
# chol_level                  Borderline
# Name: 974, dtype: object

# %%
# set of acceptable values
acceptable_values = {0, 1, 2, 3}

# outliers
outliers = data[~data['num_major_vessels'].isin(acceptable_values)]

outliers
# Out:
#           age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 48   0.187500       1                2                0.415094     0.111872
# 79   0.187500       1                2                0.415094     0.111872
# 124  0.479167       1                2                0.415094     0.221461
# 203  0.187500       1                2                0.415094     0.111872
# 237  0.187500       1                2                0.415094     0.111872
# 285  0.479167       1                2                0.415094     0.221461
# 335  0.187500       1                2                0.415094     0.111872
# 343  0.291667       1                0                0.358491     0.276256
# 411  0.479167       1                2                0.415094     0.221461
# 422  0.291667       1                0                0.358491     0.276256
# 459  0.187500       1                2                0.415094     0.111872
# 515  0.604167       1                1                0.292453     0.214612
# 591  0.187500       1                2                0.415094     0.111872
# 737  0.604167       1                1                0.292453     0.214612
# 743  0.604167       1                1                0.292453     0.214612
# 825  0.604167       1                1                0.292453     0.214612
# 964  0.187500       1                2                0.415094     0.111872
# 986  0.291667       1                0                0.358491     0.276256
#
#      fasting_blood_sugar  rest_electro  max_heart_rate  \
# 48                   0.0             1        0.778626
# 79                   0.0             1        0.778626
# 124                  0.0             1        0.748092
# 203                  0.0             1        0.778626
# 237                  0.0             1        0.778626
# 285                  0.0             1        0.748092
# 335                  0.0             1        0.778626
# 343                  1.0             0        0.549618
# 411                  0.0             1        0.748092
# 422                  1.0             0        0.549618
# 459                  0.0             1        0.778626
# 515                  0.0             1        0.557252
# 591                  0.0             1        0.778626
# 737                  0.0             1        0.557252
# 743                  0.0             1        0.557252
# 825                  0.0             1        0.557252
# 964                  0.0             1        0.778626
# 986                  1.0             0        0.549618
#
#      exercise_induced_angina st_depression  st_slope  num_major_vessels  thal  \
# 48                       0.0             0         2                  4     2
# 79                       0.0             0         2                  4     2
# 124                      0.0             0         2                  4     2
# 203                      0.0             0         2                  4     2
# 237                      0.0             0         2                  4     2
# 285                      0.0             0         2                  4     2
# 335                      0.0             0         2                  4     2
# 343                      1.0           0.1         1                  4     3
# 411                      0.0             0         2                  4     2
# 422                      1.0           0.1         1                  4     3
# 459                      0.0             0         2                  4     2
# 515                      0.0           0.4         1                  4     3
# 591                      0.0             0         2                  4     2
# 737                      0.0           0.4         1                  4     3
# 743                      0.0           0.4         1                  4     3
# 825                      0.0           0.4         1                  4     3
# 964                      0.0             0         2                  4     2
# 986                      1.0           0.1         1                  4     3
#
#      target    age_group  chol_level
# 48        1  Middle Aged        Good
# 79        1  Middle Aged        Good
# 124       1  Middle Aged  Borderline
# 203       1  Middle Aged        Good
# 237       1  Middle Aged        Good
# 285       1  Middle Aged  Borderline
# 335       1  Middle Aged        Good
# 343       0  Middle Aged        High
# 411       1  Middle Aged  Borderline
# 422       0  Middle Aged        High
# 459       1  Middle Aged        Good
# 515       1       Senior  Borderline
# 591       1  Middle Aged        Good
# 737       1       Senior  Borderline
# 743       1       Senior  Borderline
# 825       1       Senior  Borderline
# 964       1  Middle Aged        Good
# 986       0  Middle Aged        High

# %%
data
# Out:
#            age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0     0.479167       1                0                0.292453     0.196347
# 1     0.687500       0                0                0.415094     0.383562
# 2     0.604167       0                0                0.245283     0.278539
# 3     0.604167       1                0                0.188679     0.438356
# 4     0.541667       1                0                0.622642     0.372146
# ...        ...     ...              ...                     ...          ...
# 1013  0.625000       1                1                0.433962     0.216895
# 1014  0.645833       1                0                0.292453     0.301370
# 1015  0.375000       1                0                0.150943     0.340183
# 1016  0.437500       0                0                0.150943     0.292237
# 1017  0.520833       1                0                0.245283     0.141553
#
#       fasting_blood_sugar  rest_electro  max_heart_rate  \
# 0                     0.0             1        0.740458
# 1                     1.0             1        0.267176
# 2                     0.0             0        0.389313
# 3                     0.0             2        0.526718
# 4                     0.0             0        0.564885
# ...                   ...           ...             ...
# 1013                  0.0             1        0.709924
# 1014                  0.0             0        0.534351
# 1015                  0.0             0        0.358779
# 1016                  0.0             0        0.671756
# 1017                  0.0             1        0.320611
#
#       exercise_induced_angina st_depression  st_slope  num_major_vessels  \
# 0                         0.0             1         2                  2
# 1                         0.0           1.9         1                  3
# 2                         0.0             1         1                  0
# 3                         0.0           4.4         0                  3
# 4                         0.0           0.8         1                  1
# ...                       ...           ...       ...                ...
# 1013                      1.0             0         2                  0
# 1014                      1.0           2.8         1                  1
# 1015                      1.0             1         1                  1
# 1016                      0.0             0         2                  0
# 1017                      0.0           1.4         1                  1
#
#       thal  target    age_group  chol_level
# 0        3       0  Middle Aged  Borderline
# 1        2       0       Senior        High
# 2        2       1       Senior        High
# 3        1       0       Senior        High
# 4        3       0  Middle Aged        High
# ...    ...     ...          ...         ...
# 1013     2       1       Senior  Borderline
# 1014     3       0       Senior        High
# 1015     2       0  Middle Aged        High
# 1016     2       1  Middle Aged        High
# 1017     3       0  Middle Aged        Good
#
# [1018 rows x 16 columns]

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# Generate histograms for each column 
data.hist(figsize=(14, 10)) 
plt.show()

# %%
#2 Categorical Encoding – Ordinal/Label Encoder
from sklearn.preprocessing import LabelEncoder

# Encode non-numeric columns
encoder = LabelEncoder()
data['st_depression'] = encoder.fit_transform(data['st_depression'])
data['age_group'] = encoder.fit_transform(data['age_group'])
data['chol_level'] = encoder.fit_transform(data['chol_level'])

# %%
from sklearn.model_selection import train_test_split as tts

# Split the data into training and testing sets
trainSet, testSet = tts(data, test_size=0.3)

trainSet
# Out:
#            age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 772   0.625000       1                3                0.377358     0.178082
# 214   0.520833       1                0                0.264151     0.365297
# 881   0.583333       1                0                0.150943     0.171233
# 408   0.625000       1                3                0.716981     0.369863
# 756   0.562500       1                1                0.339623     0.216895
# ...        ...     ...              ...                     ...          ...
# 43    0.770833       0                0                0.792453     0.232877
# 653   0.625000       1                0                0.415094     0.331050
# 1012  0.375000       1                0                0.169811     0.178082
# 957   0.583333       0                0                0.433962     0.262557
# 845   0.166667       1                2                0.339623     0.283105
#
#       fasting_blood_sugar  rest_electro  max_heart_rate  \
# 772                   0.0             1        0.694656
# 214                   0.0             0        0.343511
# 881                   0.0             1        0.419847
# 408                   0.0             0        0.671756
# 756                   0.0             0        0.702290
# ...                   ...           ...             ...
# 43                    1.0             1        0.717557
# 653                   0.0             0        0.847328
# 1012                  0.0             1        0.549618
# 957                   0.0             1        0.396947
# 845                   0.0             1        0.885496
#
#       exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 772                       0.0              8         2                  2
# 214                       1.0             30         1                  2
# 881                       1.0             15         1                  0
# 408                       0.0              2         1                  0
# 756                       0.0             40         2                  0
# ...                       ...            ...       ...                ...
# 43                        1.0             10         1                  2
# 653                       0.0              0         2                  0
# 1012                      0.0              1         2                  0
# 957                       1.0              2         1                  0
# 845                       0.0             32         0                  0
#
#       thal  target  age_group  chol_level
# 772      2       0          1           0
# 214      2       0          0           2
# 881      1       1          1           0
# 408      3       0          1           2
# 756      3       1          1           0
# ...    ...     ...        ...         ...
# 43       3       0          1           0
# 653      2       1          1           2
# 1012     2       1          0           0
# 957      3       0          1           2
# 845      2       1          0           2
#
# [712 rows x 16 columns]

# %%
testSet
# Out:
#           age  gender  chest_pain_type  resting_blood_pressure  cholesterol  \
# 614  0.583333       1                0                0.547170     0.337900
# 21   0.666667       0                0                0.481132     0.413242
# 937  0.750000       1                0                0.245283     0.116438
# 985  0.437500       0                0                0.150943     0.292237
# 571  0.854167       1                0                0.339623     0.447489
# ..        ...     ...              ...                     ...          ...
# 830  0.500000       0                0                0.415094     0.246575
# 664  0.666667       0                0                0.339623     0.465753
# 293  0.125000       1                1                0.264151     0.150685
# 422  0.291667       1                0                0.358491     0.276256
# 374  0.604167       1                0                0.490566     0.210046
#
#      fasting_blood_sugar  rest_electro  max_heart_rate  \
# 614                  0.0             1        0.129771
# 21                   0.0             0        0.572519
# 937                  0.0             1        0.526718
# 985                  0.0             0        0.671756
# 571                  0.0             0        0.290076
# ..                   ...           ...             ...
# 830                  0.0             0        0.679389
# 664                  0.0             0        0.748092
# 293                  0.0             1        0.786260
# 422                  1.0             0        0.549618
# 374                  0.0             1        0.259542
#
#      exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 614                      1.0             12         1                  1
# 21                       1.0             10         1                  0
# 937                      0.0              4         2                  0
# 985                      0.0              0         2                  0
# 571                      0.0             23         1                  3
# ..                       ...            ...       ...                ...
# 830                      0.0              0         2                  0
# 664                      0.0              0         2                  0
# 293                      0.0              0         2                  0
# 422                      1.0              1         1                  4
# 374                      0.0             19         1                  1
#
#      thal  target  age_group  chol_level
# 614     3       0          1           2
# 21      3       0          1           2
# 937     3       1          1           1
# 985     2       1          0           2
# 571     2       0          1           2
# ..    ...     ...        ...         ...
# 830     2       1          0           0
# 664     2       0          1           2
# 293     2       1          2           1
# 422     3       0          0           2
# 374     3       0          1           0
#
# [306 rows x 16 columns]

# %%
testSet.to_csv('testSet.csv')
trainSet.to_csv('trainSet.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      1018 non-null   float64
#  1   gender                   1018 non-null   int64
#  2   chest_pain_type          1018 non-null   int64
#  3   resting_blood_pressure   1018 non-null   float64
#  4   cholesterol              1018 non-null   float64
#  5   fasting_blood_sugar      1018 non-null   float64
#  6   rest_electro             1018 non-null   int64
#  7   max_heart_rate           1018 non-null   float64
#  8   exercise_induced_angina  1018 non-null   float64
#  9   st_depression            1018 non-null   int32
#  10  st_slope                 1018 non-null   int64
#  11  num_major_vessels        1018 non-null   int64
#  12  thal                     1018 non-null   int64
#  13  target                   1018 non-null   int32
#  14  age_group                1018 non-null   int32
#  15  chol_level               1018 non-null   int32
# dtypes: float64(6), int32(4), int64(6)
# memory usage: 111.5 KB

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split as tts

# we should encode non-numeric columns priviously LogisticRegression deal with numerics

# Separate features and target
train_features = trainSet.drop('target', axis=1)
train_target = trainSet['target']
test_features = testSet.drop('target', axis=1)
test_target = testSet['target']

# Train the model
model = LogisticRegression(max_iter=2000)  
model.fit(train_features, train_target)

# Predict on the test set
predictions = model.predict(test_features)

# Calculate scores as percentages
accuracy = accuracy_score(test_target, predictions) * 100
precision = precision_score(test_target, predictions) * 100
recall = recall_score(test_target, predictions) * 100

# Print scores
print(f"Accuracy: {accuracy:.2f}%")
print(f"Precision: {precision:.2f}%")
print(f"Recall: {recall:.2f}%")
# Out:
# Accuracy: 82.35%
# Precision: 76.51%
# Recall: 89.44%
